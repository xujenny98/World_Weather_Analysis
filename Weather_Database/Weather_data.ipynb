# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import random
from citipy import citipy
from config import weather_api_key
from config import g_key
from datetime import datetime
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        # challenge objective to use 2 try and except blocks to set rain and snow when there's no data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        try:
            city_snow = city_weather["snow"]["1h"]
        except KeyError:
                city_snow = 0 
        try:            
            city_rain = city_weather["rain"]["1h"]
        except KeyError: 
                city_rain = 0
                
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping..." + city.title())
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...Belushya Guba
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | uberlandia
# Processing Record 5 of Set 1 | grand river south east
# City not found. Skipping...Grand River South East
# Processing Record 6 of Set 1 | zeya
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | arlit
# Processing Record 9 of Set 1 | rockland
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | kargapolye
# City not found. Skipping...Kargapolye
# Processing Record 13 of Set 1 | derzhavinsk
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | bom jesus
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | cabedelo
# Processing Record 21 of Set 1 | fortuna
# Processing Record 22 of Set 1 | ylojarvi
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | may pen
# Processing Record 25 of Set 1 | los llanos de aridane
# Processing Record 26 of Set 1 | leningradskiy
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | zlatoustovsk
# City not found. Skipping...Zlatoustovsk
# Processing Record 31 of Set 1 | davidson
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | caucaia
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | rocha
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | muisne
# Processing Record 44 of Set 1 | saint-francois
# Processing Record 45 of Set 1 | staromyshastovskaya
# Processing Record 46 of Set 1 | lavrentiya
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | pacific grove
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | kununurra
# Processing Record 2 of Set 2 | siteki
# Processing Record 3 of Set 2 | labuan
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...Mys Shmidta
# Processing Record 5 of Set 2 | conde
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | tsihombe
# City not found. Skipping...Tsihombe
# Processing Record 8 of Set 2 | pervomayskiy
# Processing Record 9 of Set 2 | beringovskiy
# Processing Record 10 of Set 2 | sorvag
# City not found. Skipping...Sorvag
# Processing Record 11 of Set 2 | vestmannaeyjar
# Processing Record 12 of Set 2 | hirara
# Processing Record 13 of Set 2 | takoradi
# Processing Record 14 of Set 2 | vila velha
# Processing Record 15 of Set 2 | vila
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | majene
# Processing Record 18 of Set 2 | omsukchan
# Processing Record 19 of Set 2 | aswan
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...Taolanaro
# Processing Record 22 of Set 2 | taoudenni
# Processing Record 23 of Set 2 | gazanjyk
# Processing Record 24 of Set 2 | shepsi
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | cassilandia
# Processing Record 27 of Set 2 | havelock
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | rikitea
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | bilma
# Processing Record 36 of Set 2 | pasni
# Processing Record 37 of Set 2 | hihifo
# City not found. Skipping...Hihifo
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | sao geraldo do araguaia
# Processing Record 42 of Set 2 | miyako
# Processing Record 43 of Set 2 | flinders
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | sao joao da barra
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...Illoqqortoormiut
# Processing Record 47 of Set 2 | kailua
# Processing Record 48 of Set 2 | port hardy
# Processing Record 49 of Set 2 | kieta
# Processing Record 50 of Set 2 | mar del plata
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | sao miguel do araguaia
# Processing Record 4 of Set 3 | leo
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | shiyan
# Processing Record 7 of Set 3 | bilibino
# Processing Record 8 of Set 3 | tiarei
# Processing Record 9 of Set 3 | attawapiskat
# City not found. Skipping...Attawapiskat
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...Barentsburg
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | vostok
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | fare
# Processing Record 15 of Set 3 | salalah
# Processing Record 16 of Set 3 | hamilton
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | hadgaon
# Processing Record 21 of Set 3 | krasnoselkup
# Processing Record 22 of Set 3 | vaitupu
# City not found. Skipping...Vaitupu
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | hobyo
# Processing Record 25 of Set 3 | iquique
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | cooma
# Processing Record 28 of Set 3 | lebu
# Processing Record 29 of Set 3 | qaqortoq
# Processing Record 30 of Set 3 | athabasca
# Processing Record 31 of Set 3 | margate
# Processing Record 32 of Set 3 | arrifes
# Processing Record 33 of Set 3 | havoysund
# Processing Record 34 of Set 3 | mrirt
# City not found. Skipping...Mrirt
# Processing Record 35 of Set 3 | port hedland
# Processing Record 36 of Set 3 | tateyama
# Processing Record 37 of Set 3 | batemans bay
# Processing Record 38 of Set 3 | neiafu
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | fukue
# Processing Record 41 of Set 3 | dumas
# Processing Record 42 of Set 3 | saint george
# Processing Record 43 of Set 3 | saldus
# Processing Record 44 of Set 3 | pousat
# City not found. Skipping...Pousat
# Processing Record 45 of Set 3 | mosquera
# Processing Record 46 of Set 3 | nioro
# Processing Record 47 of Set 3 | grand gaube
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | lorengau
# Processing Record 50 of Set 3 | east london
# Processing Record 1 of Set 4 | ciampino
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | touros
# Processing Record 4 of Set 4 | cayenne
# Processing Record 5 of Set 4 | kavaratti
# Processing Record 6 of Set 4 | karratha
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | charyshskoye
# Processing Record 9 of Set 4 | poirino
# Processing Record 10 of Set 4 | port lincoln
# Processing Record 11 of Set 4 | watrous
# Processing Record 12 of Set 4 | kirensk
# Processing Record 13 of Set 4 | merrill
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | abrau-dyurso
# Processing Record 16 of Set 4 | calabar
# Processing Record 17 of Set 4 | enshi
# Processing Record 18 of Set 4 | nouakchott
# Processing Record 19 of Set 4 | vila franca do campo
# Processing Record 20 of Set 4 | whitehorse
# Processing Record 21 of Set 4 | srednekolymsk
# Processing Record 22 of Set 4 | mayo
# Processing Record 23 of Set 4 | chibombo
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...Amderma
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | milazzo
# Processing Record 27 of Set 4 | castro
# Processing Record 28 of Set 4 | paamiut
# Processing Record 29 of Set 4 | gilgil
# City not found. Skipping...Gilgil
# Processing Record 30 of Set 4 | esperance
# Processing Record 31 of Set 4 | griffith
# Processing Record 32 of Set 4 | hualmay
# Processing Record 33 of Set 4 | carutapera
# Processing Record 34 of Set 4 | myre
# Processing Record 35 of Set 4 | provideniya
# Processing Record 36 of Set 4 | kloulklubed
# Processing Record 37 of Set 4 | lolua
# City not found. Skipping...Lolua
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | cananeia
# Processing Record 40 of Set 4 | pisco
# Processing Record 41 of Set 4 | cairns
# Processing Record 42 of Set 4 | kushmurun
# Processing Record 43 of Set 4 | port-gentil
# Processing Record 44 of Set 4 | kazachinskoye
# Processing Record 45 of Set 4 | bangkalan
# Processing Record 46 of Set 4 | mananjary
# Processing Record 47 of Set 4 | praya
# Processing Record 48 of Set 4 | katsuura
# Processing Record 49 of Set 4 | preobrazheniye
# Processing Record 50 of Set 4 | chaman
# Processing Record 1 of Set 5 | sirohi
# Processing Record 2 of Set 5 | alto piquiri
# Processing Record 3 of Set 5 | mugur-aksy
# Processing Record 4 of Set 5 | carnarvon
# Processing Record 5 of Set 5 | ust-omchug
# Processing Record 6 of Set 5 | namyslow
# Processing Record 7 of Set 5 | dubbo
# Processing Record 8 of Set 5 | urumqi
# Processing Record 9 of Set 5 | podyuga
# Processing Record 10 of Set 5 | halifax
# Processing Record 11 of Set 5 | kaduqli
# Processing Record 12 of Set 5 | moron
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | avera
# Processing Record 15 of Set 5 | bagdarin
# Processing Record 16 of Set 5 | general roca
# Processing Record 17 of Set 5 | sola
# Processing Record 18 of Set 5 | rahimatpur
# Processing Record 19 of Set 5 | pryozerne
# Processing Record 20 of Set 5 | savannah bight
# Processing Record 21 of Set 5 | padang
# Processing Record 22 of Set 5 | tazmalt
# Processing Record 23 of Set 5 | ahipara
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | imbituba
# Processing Record 26 of Set 5 | christchurch
# Processing Record 27 of Set 5 | okitipupa
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | sisimiut
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...Palabuhanratu
# Processing Record 31 of Set 5 | altoona
# Processing Record 32 of Set 5 | pangkalanbuun
# Processing Record 33 of Set 5 | shaikhpura
# Processing Record 34 of Set 5 | saint-gedeon
# Processing Record 35 of Set 5 | clyde river
# Processing Record 36 of Set 5 | tekax
# City not found. Skipping...Tekax
# Processing Record 37 of Set 5 | rio gallegos
# Processing Record 38 of Set 5 | bonthe
# Processing Record 39 of Set 5 | mount gambier
# Processing Record 40 of Set 5 | inuvik
# Processing Record 41 of Set 5 | fez
# Processing Record 42 of Set 5 | marinhas
# Processing Record 43 of Set 5 | lanigan
# Processing Record 44 of Set 5 | faya
# Processing Record 45 of Set 5 | clemencia
# Processing Record 46 of Set 5 | santa isabel do rio negro
# Processing Record 47 of Set 5 | huejuquilla el alto
# Processing Record 48 of Set 5 | cape town
# Processing Record 49 of Set 5 | saquarema
# Processing Record 50 of Set 5 | nhulunbuy
# Processing Record 1 of Set 6 | temirtau
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | cuenca
# Processing Record 4 of Set 6 | qandala
# Processing Record 5 of Set 6 | samalaeulu
# City not found. Skipping...Samalaeulu
# Processing Record 6 of Set 6 | lichtenburg
# Processing Record 7 of Set 6 | daman
# Processing Record 8 of Set 6 | zhanaozen
# Processing Record 9 of Set 6 | krasnik
# Processing Record 10 of Set 6 | shetpe
# Processing Record 11 of Set 6 | aljezur
# Processing Record 12 of Set 6 | portland
# Processing Record 13 of Set 6 | davila
# Processing Record 14 of Set 6 | riviere-au-renard
# Processing Record 15 of Set 6 | cherskiy
# Processing Record 16 of Set 6 | maloy
# Processing Record 17 of Set 6 | rungata
# City not found. Skipping...Rungata
# Processing Record 18 of Set 6 | olga
# Processing Record 19 of Set 6 | coahuayana
# Processing Record 20 of Set 6 | saint-louis
# Processing Record 21 of Set 6 | lubu
# Processing Record 22 of Set 6 | nishihara
# Processing Record 23 of Set 6 | komsomolskiy
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | juifang
# City not found. Skipping...Juifang
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | tokmak
# Processing Record 28 of Set 6 | namibe
# Processing Record 29 of Set 6 | coos bay
# Processing Record 30 of Set 6 | talara
# Processing Record 31 of Set 6 | kristiansund
# Processing Record 32 of Set 6 | haines junction
# Processing Record 33 of Set 6 | lakes entrance
# Processing Record 34 of Set 6 | izhma
# Processing Record 35 of Set 6 | miandrivazo
# Processing Record 36 of Set 6 | karauzyak
# City not found. Skipping...Karauzyak
# Processing Record 37 of Set 6 | bandarbeyla
# Processing Record 38 of Set 6 | oktyabrskoye
# Processing Record 39 of Set 6 | suntar
# Processing Record 40 of Set 6 | vegreville
# Processing Record 41 of Set 6 | alta floresta
# Processing Record 42 of Set 6 | mongar
# Processing Record 43 of Set 6 | bom jardim
# Processing Record 44 of Set 6 | sassandra
# Processing Record 45 of Set 6 | mullaitivu
# City not found. Skipping...Mullaitivu
# Processing Record 46 of Set 6 | tukrah
# Processing Record 47 of Set 6 | puerto colombia
# Processing Record 48 of Set 6 | tela
# Processing Record 49 of Set 6 | pointe michel
# Processing Record 50 of Set 6 | belyy yar
# Processing Record 1 of Set 7 | biak
# Processing Record 2 of Set 7 | namatanai
# Processing Record 3 of Set 7 | mpanda
# Processing Record 4 of Set 7 | puebloviejo
# Processing Record 5 of Set 7 | disna
# Processing Record 6 of Set 7 | saleaula
# City not found. Skipping...Saleaula
# Processing Record 7 of Set 7 | bubaque
# Processing Record 8 of Set 7 | freeport
# Processing Record 9 of Set 7 | pangnirtung
# Processing Record 10 of Set 7 | terrace
# Processing Record 11 of Set 7 | sistranda
# Processing Record 12 of Set 7 | san juan
# Processing Record 13 of Set 7 | lompoc
# Processing Record 14 of Set 7 | sapulpa
# Processing Record 15 of Set 7 | hervey bay
# Processing Record 16 of Set 7 | anton lizardo
# Processing Record 17 of Set 7 | svetlogorsk
# Processing Record 18 of Set 7 | udala
# Processing Record 19 of Set 7 | severo-yeniseyskiy
# Processing Record 20 of Set 7 | jinchang
# Processing Record 21 of Set 7 | saint-philippe
# Processing Record 22 of Set 7 | camacupa
# Processing Record 23 of Set 7 | bambous virieux
# Processing Record 24 of Set 7 | enzan
# Processing Record 25 of Set 7 | tsagan aman
# Processing Record 26 of Set 7 | guerrero negro
# Processing Record 27 of Set 7 | cervo
# Processing Record 28 of Set 7 | okhotsk
# Processing Record 29 of Set 7 | chulman
# Processing Record 30 of Set 7 | georgetown
# Processing Record 31 of Set 7 | goderich
# Processing Record 32 of Set 7 | yanam
# Processing Record 33 of Set 7 | nizhneyansk
# City not found. Skipping...Nizhneyansk
# Processing Record 34 of Set 7 | shingu
# Processing Record 35 of Set 7 | la paz centro
# Processing Record 36 of Set 7 | chuy
# Processing Record 37 of Set 7 | rio grande
# Processing Record 38 of Set 7 | gimli
# Processing Record 39 of Set 7 | dingle
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | ust-kulom
# Processing Record 42 of Set 7 | puerto del rosario
# Processing Record 43 of Set 7 | iroquois
# Processing Record 44 of Set 7 | tabuk
# Processing Record 45 of Set 7 | kuching
# Processing Record 46 of Set 7 | half moon bay
# Processing Record 47 of Set 7 | camacha
# Processing Record 48 of Set 7 | remanso
# Processing Record 49 of Set 7 | san borja
# Processing Record 50 of Set 7 | sao pedro do sul
# Processing Record 1 of Set 8 | boguchany
# Processing Record 2 of Set 8 | alexandria
# Processing Record 3 of Set 8 | vardo
# Processing Record 4 of Set 8 | yar-sale
# Processing Record 5 of Set 8 | fomboni
# Processing Record 6 of Set 8 | riyadh
# Processing Record 7 of Set 8 | gunjur
# Processing Record 8 of Set 8 | ternate
# Processing Record 9 of Set 8 | islampur
# Processing Record 10 of Set 8 | nambutalai
# Processing Record 11 of Set 8 | portadown
# Processing Record 12 of Set 8 | sao filipe
# Processing Record 13 of Set 8 | itacarambi
# Processing Record 14 of Set 8 | barawe
# City not found. Skipping...Barawe
# Processing Record 15 of Set 8 | roald
# Processing Record 16 of Set 8 | billings
# Processing Record 17 of Set 8 | zheleznodorozhnyy
# Processing Record 18 of Set 8 | isangel
# Processing Record 19 of Set 8 | tecoanapa
# Processing Record 20 of Set 8 | husavik
# Processing Record 21 of Set 8 | hofn
# Processing Record 22 of Set 8 | daru
# Processing Record 23 of Set 8 | kargopol
# Processing Record 24 of Set 8 | ziyang
# Processing Record 25 of Set 8 | kirakira
# Processing Record 26 of Set 8 | ishigaki
# Processing Record 27 of Set 8 | coihaique
# Processing Record 28 of Set 8 | murgab
# Processing Record 29 of Set 8 | ponta delgada
# Processing Record 30 of Set 8 | lodja
# Processing Record 31 of Set 8 | bolshaya glushitsa
# Processing Record 32 of Set 8 | faanui
# Processing Record 33 of Set 8 | fairbanks
# Processing Record 34 of Set 8 | bereda
# Processing Record 35 of Set 8 | kijang
# Processing Record 36 of Set 8 | tautira
# Processing Record 37 of Set 8 | umzimvubu
# City not found. Skipping...Umzimvubu
# Processing Record 38 of Set 8 | tubruq
# City not found. Skipping...Tubruq
# Processing Record 39 of Set 8 | messina
# Processing Record 40 of Set 8 | kamenskoye
# City not found. Skipping...Kamenskoye
# Processing Record 41 of Set 8 | farmington
# Processing Record 42 of Set 8 | seshcha
# Processing Record 43 of Set 8 | tamasane
# Processing Record 44 of Set 8 | nshamba
# Processing Record 45 of Set 8 | trairi
# Processing Record 46 of Set 8 | turukhansk
# Processing Record 47 of Set 8 | makushino
# Processing Record 48 of Set 8 | muncar
# Processing Record 49 of Set 8 | shubarkuduk
# Processing Record 50 of Set 8 | alipur
# Processing Record 1 of Set 9 | at-bashi
# Processing Record 2 of Set 9 | puerto maldonado
# Processing Record 3 of Set 9 | akyab
# Processing Record 4 of Set 9 | shimoda
# Processing Record 5 of Set 9 | acapulco
# Processing Record 6 of Set 9 | juchipila
# Processing Record 7 of Set 9 | codrington
# Processing Record 8 of Set 9 | caravelas
# Processing Record 9 of Set 9 | alice springs
# Processing Record 10 of Set 9 | lata
# Processing Record 11 of Set 9 | rio cuarto
# Processing Record 12 of Set 9 | nokaneng
# Processing Record 13 of Set 9 | fort nelson
# Processing Record 14 of Set 9 | xichang
# Processing Record 15 of Set 9 | merauke
# Processing Record 16 of Set 9 | tanout
# Processing Record 17 of Set 9 | lensk
# Processing Record 18 of Set 9 | beawar
# Processing Record 19 of Set 9 | bolungarvik
# City not found. Skipping...Bolungarvik
# Processing Record 20 of Set 9 | tura
# Processing Record 21 of Set 9 | naliya
# Processing Record 22 of Set 9 | greencastle
# Processing Record 23 of Set 9 | beruwala
# Processing Record 24 of Set 9 | maceio
# Processing Record 25 of Set 9 | high level
# Processing Record 26 of Set 9 | stornoway
# Processing Record 27 of Set 9 | natal
# Processing Record 28 of Set 9 | mitsamiouli
# Processing Record 29 of Set 9 | comodoro rivadavia
# Processing Record 30 of Set 9 | mutterstadt
# Processing Record 31 of Set 9 | aasiaat
# Processing Record 32 of Set 9 | peniche
# Processing Record 33 of Set 9 | nanortalik
# Processing Record 34 of Set 9 | chengde
# Processing Record 35 of Set 9 | bolshiye uki
# City not found. Skipping...Bolshiye Uki
# Processing Record 36 of Set 9 | nouadhibou
# Processing Record 37 of Set 9 | ulladulla
# Processing Record 38 of Set 9 | sechura
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | rawannawi
# City not found. Skipping...Rawannawi
# Processing Record 41 of Set 9 | nemuro
# Processing Record 42 of Set 9 | tres lagoas
# Processing Record 43 of Set 9 | tatarsk
# Processing Record 44 of Set 9 | samusu
# City not found. Skipping...Samusu
# Processing Record 45 of Set 9 | jamiltepec
# Processing Record 46 of Set 9 | northam
# Processing Record 47 of Set 9 | the valley
# Processing Record 48 of Set 9 | aklavik
# Processing Record 49 of Set 9 | san-pedro
# Processing Record 50 of Set 9 | port blair
# Processing Record 1 of Set 10 | libenge
# Processing Record 2 of Set 10 | port said
# Processing Record 3 of Set 10 | atherton
# Processing Record 4 of Set 10 | santa cruz cabralia
# Processing Record 5 of Set 10 | erenhot
# Processing Record 6 of Set 10 | asau
# Processing Record 7 of Set 10 | sungaipenuh
# Processing Record 8 of Set 10 | garowe
# Processing Record 9 of Set 10 | vilhena
# Processing Record 10 of Set 10 | sentyabrskiy
# City not found. Skipping...Sentyabrskiy
# Processing Record 11 of Set 10 | labuhan
# Processing Record 12 of Set 10 | nara
# Processing Record 13 of Set 10 | saint-augustin
# Processing Record 14 of Set 10 | ujjain
# Processing Record 15 of Set 10 | liepaja
# Processing Record 16 of Set 10 | moree
# Processing Record 17 of Set 10 | washougal
# Processing Record 18 of Set 10 | buala
# Processing Record 19 of Set 10 | nyimba
# Processing Record 20 of Set 10 | gzhatsk
# City not found. Skipping...Gzhatsk
# Processing Record 21 of Set 10 | leshan
# Processing Record 22 of Set 10 | aksu
# Processing Record 23 of Set 10 | dafeng
# Processing Record 24 of Set 10 | itoman
# Processing Record 25 of Set 10 | trinidad
# Processing Record 26 of Set 10 | ribeira grande
# Processing Record 27 of Set 10 | emiliano zapata
# Processing Record 28 of Set 10 | aromashevo
# Processing Record 29 of Set 10 | malakal
# Processing Record 30 of Set 10 | broome
# Processing Record 31 of Set 10 | kostomuksha
# Processing Record 32 of Set 10 | krasnokholm
# Processing Record 33 of Set 10 | katherine
# Processing Record 34 of Set 10 | tual
# Processing Record 35 of Set 10 | medicine hat
# Processing Record 36 of Set 10 | chhindwara
# Processing Record 37 of Set 10 | nguiu
# City not found. Skipping...Nguiu
# Processing Record 38 of Set 10 | trat
# Processing Record 39 of Set 10 | kawalu
# Processing Record 40 of Set 10 | te anau
# Processing Record 41 of Set 10 | antalaha
# Processing Record 42 of Set 10 | cururupu
# Processing Record 43 of Set 10 | inegol
# Processing Record 44 of Set 10 | saucillo
# Processing Record 45 of Set 10 | alanya
# Processing Record 46 of Set 10 | nisia floresta
# Processing Record 47 of Set 10 | coetupo
# City not found. Skipping...Coetupo
# Processing Record 48 of Set 10 | necochea
# Processing Record 49 of Set 10 | pandan
# Processing Record 50 of Set 10 | nasaud
# Processing Record 1 of Set 11 | emerald
# Processing Record 2 of Set 11 | kachiry
# Processing Record 3 of Set 11 | gat
# Processing Record 4 of Set 11 | yialos
# City not found. Skipping...Yialos
# Processing Record 5 of Set 11 | baiyin
# Processing Record 6 of Set 11 | montepuez
# Processing Record 7 of Set 11 | marcona
# City not found. Skipping...Marcona
# Processing Record 8 of Set 11 | harper
# Processing Record 9 of Set 11 | saldanha
# Processing Record 10 of Set 11 | magadan
# Processing Record 11 of Set 11 | korla
# Processing Record 12 of Set 11 | hami
# Processing Record 13 of Set 11 | aloleng
# Processing Record 14 of Set 11 | nerchinskiy zavod
# Processing Record 15 of Set 11 | prabumulih
# Processing Record 16 of Set 11 | sitka
# Processing Record 17 of Set 11 | ankara
# Processing Record 18 of Set 11 | haibowan
# City not found. Skipping...Haibowan
# Processing Record 19 of Set 11 | dourbali
# Processing Record 20 of Set 11 | wajima
# Processing Record 21 of Set 11 | lethem
# Processing Record 22 of Set 11 | bathsheba
# Processing Record 23 of Set 11 | north bend
# Processing Record 24 of Set 11 | manta
# Processing Record 25 of Set 11 | isiro
# Processing Record 26 of Set 11 | santo angelo
# Processing Record 27 of Set 11 | jarva-jaani
# Processing Record 28 of Set 11 | burnie
# Processing Record 29 of Set 11 | dolores
# Processing Record 30 of Set 11 | fallon
# Processing Record 31 of Set 11 | quelimane
# Processing Record 32 of Set 11 | naze
# Processing Record 33 of Set 11 | buchanan
# Processing Record 34 of Set 11 | hambantota
# Processing Record 35 of Set 11 | elk
# Processing Record 36 of Set 11 | yumen
# Processing Record 37 of Set 11 | aligudarz
# Processing Record 38 of Set 11 | oranjemund
# Processing Record 39 of Set 11 | llandrindod wells
# Processing Record 40 of Set 11 | itabira
# Processing Record 41 of Set 11 | hay river
# Processing Record 42 of Set 11 | tessalit
# Processing Record 43 of Set 11 | impfondo
# Processing Record 44 of Set 11 | yulara
# Processing Record 45 of Set 11 | camopi
# Processing Record 46 of Set 11 | pimentel
# Processing Record 47 of Set 11 | pital
# Processing Record 48 of Set 11 | mount isa
# Processing Record 49 of Set 11 | khairagarh
# Processing Record 50 of Set 11 | baykalovo
# Processing Record 1 of Set 12 | ilulissat
# Processing Record 2 of Set 12 | tidore
# City not found. Skipping...Tidore
# Processing Record 3 of Set 12 | dunedin
# Processing Record 4 of Set 12 | jalalpur pirwala
# Processing Record 5 of Set 12 | dwarka
# Processing Record 6 of Set 12 | helong
# Processing Record 7 of Set 12 | kashan
# Processing Record 8 of Set 12 | capleni
# Processing Record 9 of Set 12 | ostrovnoy
# Processing Record 10 of Set 12 | ailigandi
# Processing Record 11 of Set 12 | leh
# Processing Record 12 of Set 12 | srandakan
# Processing Record 13 of Set 12 | paulista
# Processing Record 14 of Set 12 | bella vista
# Processing Record 15 of Set 12 | narsaq
# Processing Record 16 of Set 12 | moen
# Processing Record 17 of Set 12 | talaya
# Processing Record 18 of Set 12 | orikum
# Processing Record 19 of Set 12 | lasa
# Processing Record 20 of Set 12 | topolovgrad
# Processing Record 21 of Set 12 | cortes
# Processing Record 22 of Set 12 | banikoara
# Processing Record 23 of Set 12 | rovenki
# Processing Record 24 of Set 12 | hosdurga
# Processing Record 25 of Set 12 | cienfuegos
# Processing Record 26 of Set 12 | vanimo
# Processing Record 27 of Set 12 | ratnagiri
# Processing Record 28 of Set 12 | morrope
# Processing Record 29 of Set 12 | verkhnevilyuysk
# Processing Record 30 of Set 12 | alofi
# Processing Record 31 of Set 12 | sivas
# Processing Record 32 of Set 12 | mallapuram
# Processing Record 33 of Set 12 | garwa
# Processing Record 34 of Set 12 | lubumbashi
# Processing Record 35 of Set 12 | warrnambool
# Processing Record 36 of Set 12 | uwayl
# City not found. Skipping...Uwayl
# Processing Record 37 of Set 12 | tezu
# Processing Record 38 of Set 12 | arnprior
# Processing Record 39 of Set 12 | burica
# City not found. Skipping...Burica
# Processing Record 40 of Set 12 | bollnas
# Processing Record 41 of Set 12 | lucapa
# Processing Record 42 of Set 12 | abha
# Processing Record 43 of Set 12 | japura
# Processing Record 44 of Set 12 | teya
# Processing Record 45 of Set 12 | gitarama
# Processing Record 46 of Set 12 | bethanien
# Processing Record 47 of Set 12 | paraiso
# Processing Record 48 of Set 12 | san cristobal
# Processing Record 49 of Set 12 | megion
# Processing Record 50 of Set 12 | eyl
# Processing Record 1 of Set 13 | fort saint james
# Processing Record 2 of Set 13 | nizhniy baskunchak
# Processing Record 3 of Set 13 | la ronge
# Processing Record 4 of Set 13 | nago
# Processing Record 5 of Set 13 | california city
# Processing Record 6 of Set 13 | troitskoye
# Processing Record 7 of Set 13 | santa vitoria do palmar
# Processing Record 8 of Set 13 | wiang sa
# Processing Record 9 of Set 13 | honningsvag
# Processing Record 10 of Set 13 | prenzlau
# Processing Record 11 of Set 13 | atar
# Processing Record 12 of Set 13 | ngerengere
# Processing Record 13 of Set 13 | andros town
# Processing Record 14 of Set 13 | ruatoria
# City not found. Skipping...Ruatoria
# Processing Record 15 of Set 13 | lipari
# Processing Record 16 of Set 13 | scarborough
# Processing Record 17 of Set 13 | camanci
# City not found. Skipping...Camanci
# Processing Record 18 of Set 13 | wewak
# Processing Record 19 of Set 13 | cristalina
# Processing Record 20 of Set 13 | galesong
# Processing Record 21 of Set 13 | port macquarie
# Processing Record 22 of Set 13 | mount juliet
# Processing Record 23 of Set 13 | wahran
# City not found. Skipping...Wahran
# Processing Record 24 of Set 13 | ambanja
# Processing Record 25 of Set 13 | gdansk
# Processing Record 26 of Set 13 | salinopolis
# Processing Record 27 of Set 13 | manzhouli
# Processing Record 28 of Set 13 | hit
# Processing Record 29 of Set 13 | beira
# Processing Record 30 of Set 13 | tabou
# Processing Record 31 of Set 13 | turinsk
# Processing Record 32 of Set 13 | kasama
# Processing Record 33 of Set 13 | conceicao do araguaia
# Processing Record 34 of Set 13 | zhigansk
# Processing Record 35 of Set 13 | waingapu
# Processing Record 36 of Set 13 | sao gabriel da cachoeira
# Processing Record 37 of Set 13 | villa carlos paz
# Processing Record 38 of Set 13 | jahrom
# City not found. Skipping...Jahrom
# Processing Record 39 of Set 13 | micheweni
# Processing Record 40 of Set 13 | el wasta
# City not found. Skipping...El Wasta
# Processing Record 41 of Set 13 | jati
# Processing Record 42 of Set 13 | monaco-ville
# Processing Record 43 of Set 13 | robertsport
# Processing Record 44 of Set 13 | dzhusaly
# City not found. Skipping...Dzhusaly
# Processing Record 45 of Set 13 | inhambane
# Processing Record 46 of Set 13 | monrovia
# Processing Record 47 of Set 13 | saint anthony
# Processing Record 48 of Set 13 | odweyne
# Processing Record 49 of Set 13 | tocopilla
# Processing Record 50 of Set 13 | keningau
# Processing Record 1 of Set 14 | vaitape
# Processing Record 2 of Set 14 | guider
# Processing Record 3 of Set 14 | petrolandia
# City not found. Skipping...Petrolandia
# Processing Record 4 of Set 14 | khasan
# Processing Record 5 of Set 14 | gillette
# Processing Record 6 of Set 14 | awjilah
# Processing Record 7 of Set 14 | la asuncion
# Processing Record 8 of Set 14 | santa lucia
# Processing Record 9 of Set 14 | broken hill
# Processing Record 10 of Set 14 | saint-pierre
# Processing Record 11 of Set 14 | mulege
# Processing Record 12 of Set 14 | dekar
# Processing Record 13 of Set 14 | matadi
# Processing Record 14 of Set 14 | ust-nera
# Processing Record 15 of Set 14 | namwala
# Processing Record 16 of Set 14 | olafsvik
# Processing Record 17 of Set 14 | chingirlau
# Processing Record 18 of Set 14 | saint-joseph
# Processing Record 19 of Set 14 | glinka
# Processing Record 20 of Set 14 | labytnangi
# Processing Record 21 of Set 14 | otane
# Processing Record 22 of Set 14 | walvis bay
# Processing Record 23 of Set 14 | ustye
# Processing Record 24 of Set 14 | troitsko-pechorsk
# Processing Record 25 of Set 14 | tucupita
# Processing Record 26 of Set 14 | izumo
# Processing Record 27 of Set 14 | cap malheureux
# Processing Record 28 of Set 14 | surt
# Processing Record 29 of Set 14 | iznik
# Processing Record 30 of Set 14 | baglan
# Processing Record 31 of Set 14 | coquimbo
# Processing Record 32 of Set 14 | chulym
# Processing Record 33 of Set 14 | zanjan
# Processing Record 34 of Set 14 | figline valdarno
# Processing Record 35 of Set 14 | norsup
# Processing Record 36 of Set 14 | durban
# Processing Record 37 of Set 14 | aitape
# Processing Record 38 of Set 14 | yeppoon
# Processing Record 39 of Set 14 | nuevitas
# Processing Record 40 of Set 14 | gold coast
# Processing Record 41 of Set 14 | takaka
# Processing Record 42 of Set 14 | wukari
# Processing Record 43 of Set 14 | puerto escondido
# Processing Record 44 of Set 14 | havre-saint-pierre
# Processing Record 45 of Set 14 | charlestown
# Processing Record 46 of Set 14 | magaria
# Processing Record 47 of Set 14 | panjab
# Processing Record 48 of Set 14 | brae
# Processing Record 49 of Set 14 | polunochnoye
# Processing Record 50 of Set 14 | huarmey
# Processing Record 1 of Set 15 | awbari
# Processing Record 2 of Set 15 | geraldton
# Processing Record 3 of Set 15 | mirpur sakro
# Processing Record 4 of Set 15 | krasnyy chikoy
# Processing Record 5 of Set 15 | inongo
# Processing Record 6 of Set 15 | maragogi
# Processing Record 7 of Set 15 | atambua
# Processing Record 8 of Set 15 | san lazaro
# Processing Record 9 of Set 15 | taunggyi
# Processing Record 10 of Set 15 | upington
# Processing Record 11 of Set 15 | panhala
# Processing Record 12 of Set 15 | graaff-reinet
# Processing Record 13 of Set 15 | cockburn town
# Processing Record 14 of Set 15 | praia da vitoria
# Processing Record 15 of Set 15 | ixtapa
# Processing Record 16 of Set 15 | zhangye
# Processing Record 17 of Set 15 | naduvattam
# Processing Record 18 of Set 15 | juegang
# Processing Record 19 of Set 15 | tilichiki
# Processing Record 20 of Set 15 | hammerfest
# Processing Record 21 of Set 15 | shasta lake
# Processing Record 22 of Set 15 | kesinga
# Processing Record 23 of Set 15 | kikwit
# Processing Record 24 of Set 15 | richards bay
# Processing Record 25 of Set 15 | obo
# Processing Record 26 of Set 15 | kavieng
# Processing Record 27 of Set 15 | marawi
# Processing Record 28 of Set 15 | kiunga
# Processing Record 29 of Set 15 | homer
# Processing Record 30 of Set 15 | meulaboh
# Processing Record 31 of Set 15 | bundaberg
# Processing Record 32 of Set 15 | nuevo laredo
# Processing Record 33 of Set 15 | opelousas
# Processing Record 34 of Set 15 | tawau
# Processing Record 35 of Set 15 | gubkinskiy
# Processing Record 36 of Set 15 | kargasok
# Processing Record 37 of Set 15 | uray
# Processing Record 38 of Set 15 | camana
# Processing Record 39 of Set 15 | moose factory
# Processing Record 40 of Set 15 | yatou
# Processing Record 41 of Set 15 | san quintin
# Processing Record 42 of Set 15 | kawana waters
# City not found. Skipping...Kawana Waters
# Processing Record 43 of Set 15 | college
# Processing Record 44 of Set 15 | tomohon
# Processing Record 45 of Set 15 | mount darwin
# Processing Record 46 of Set 15 | ust-kuyga
# Processing Record 47 of Set 15 | oranjestad
# Processing Record 48 of Set 15 | borger
# Processing Record 49 of Set 15 | omboue
# Processing Record 50 of Set 15 | aguas vermelhas
# Processing Record 1 of Set 16 | qiongshan
# Processing Record 2 of Set 16 | goya
# Processing Record 3 of Set 16 | vrangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
# challenge objective 
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Tuktoyaktuk      CA  69.4541 -133.0374    -14.80        76
# 1             Barrow      US  71.2906 -156.7887    -20.20        69
# 2         Uberlandia      BR -18.9186  -48.2772     86.00        37
# 3               Zeya      RU  53.7500  127.2667     28.54        91
# 4              Bluff      NZ -46.6000  168.3333     57.00        99
# ..               ...     ...      ...       ...       ...       ...
# 695           Omboue      GA  -1.5746    9.2618     76.86        90
# 696  Aguas Vermelhas      BR -15.7472  -41.4600     77.04        33
# 697        Qiongshan      CN  20.0058  110.3542     75.20        94
# 698             Goya      AR -29.1400  -59.2626     70.39        63
# 699          Vrangel      RU  42.7297  133.0839     36.45        99
#
#      Cloudiness  Wind Speed Current Description
# 0            90       14.97                snow
# 1             1       10.36           clear sky
# 2            40        9.22    scattered clouds
# 3           100        6.26     overcast clouds
# 4            95        4.00     overcast clouds
# ..          ...         ...                 ...
# 695         100       10.76          light rain
# 696           0        4.83           clear sky
# 697           0        6.71           clear sky
# 698          28        7.65    scattered clouds
# 699          89        4.61          light rain
#
# [700 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
